# %% [markdown]
# # EfficientNet

# %%
# !pip install tensorflow-gpu==2.9

# %%
# !pip install opencv-python==4.5.1.48
# !pip install pandas==1.2.1
# !pip install Pillow==8.1.0
# !pip install pydicom==2.1.2
# !pip install scikit-learn==0.24.1
# !pip install scipy==1.6.0
# !pip install tqdm==4.56.0
# !pip install tikzplotlib
# !pip install efficientnet
# !pip install seaborn

# %%
import os
import cv2
import pydicom
import tikzplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import efficientnet.tfkeras as efn

# %%
import tensorflow.keras.layers as L
import tensorflow.keras.models as M
import tensorflow.keras.backend as K
from tqdm.notebook import tqdm
from tensorflow.keras import Model
from tensorflow.keras.utils import Sequence
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import GroupKFold, KFold, StratifiedKFold
from tensorflow.keras.layers import (
    Dense, Dropout, Activation, Flatten, Input, BatchNormalization, GlobalAveragePooling2D, GaussianNoise, 
    Add, Conv2D, AveragePooling2D, LeakyReLU, Concatenate 
)

# %% [markdown]
# # Load and Transform Data

# %%
train = pd.read_csv('./Dataset/train.csv')

# %%
train.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker

# %%
train['Percent'].max()
# Out:
# 153.145377828922

# %%
train['Percent'].min()
# Out:
# 28.8775766716943

# %%
train.SmokingStatus.unique()
# Out:
# array(['Ex-smoker', 'Never smoked', 'Currently smokes'], dtype=object)

# %%
def get_tab(df):
    " return an array which contains each patient normalized age, sex and smoking status"
    vector = [(df.Age.values[0] - 30) / 30] 
    
    if df.Sex.values[0].lower() == 'male':
       vector.append(0)
    else:
       vector.append(1)
    
    if df.SmokingStatus.values[0] == 'Never smoked':
        vector.extend([0,0])
    elif df.SmokingStatus.values[0] == 'Ex-smoker':
        vector.extend([1,1])
    elif df.SmokingStatus.values[0] == 'Currently smokes':
        vector.extend([0,1])
    else:
        vector.extend([1,0])
    return np.array(vector)

# %%
A = {} 
TAB = {} 
P = [] 
for i, p in tqdm(enumerate(train.Patient.unique())): # i index, p patient id
    sub = train.loc[train.Patient == p, :] # find all data (weeks, FVC, Percent, Age, Sex, SmokingStatus) of a unique patient
    fvc = sub.FVC.values # fvc values of the patient during the follow-up
    weeks = sub.Weeks.values # follow-up weeks
    c = np.vstack([weeks, np.ones(len(weeks))]).T # create an array by the follow-up weeks of shape(len(weeks),2)
    a, b = np.linalg.lstsq(c, fvc)[0] # least-square sol, a=gradient matrix, b=right hand matrix 
    
    A[p] = a
    TAB[p] = get_tab(sub)
    P.append(p)
# Out:
# 0it [00:00, ?it/s]
# C:\Users\user\Anaconda3\envs\keras-gpu\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   if __name__ == "__main__":

# %%
def get_img(path):
    " read DICOM dataset and return resize images of size (512,512,3)"
    d = pydicom.dcmread(path) # read and parse the CT scan images (in DICOM format)
    resized_image = cv2.resize((d.pixel_array - d.RescaleIntercept) / (d.RescaleSlope * 1000), (512,512))
    resized_image = np.stack((resized_image,)*3, axis = -1)
    return resized_image

# %%
class IGenerator(Sequence):
    BAD_ID = ['ID00011637202177653955184', 'ID00052637202186188008618']
    def __init__(self, keys, a, tab, batch_size):
        "key=patient, a=gradient matrix, tab=a particular patient's data"
        self.keys = [k for k in keys if k not in self.BAD_ID]
        self.a = a
        self.tab = tab
        self.batch_size = batch_size
        
        self.train_data = {}
        for p in train.Patient.values:
            self.train_data[p] = os.listdir(f'./Dataset/train/{p}/')
    
    def __len__(self):
        return 1000
    
    def __getitem__(self, idx):
        x = []
        a, tab = [], [] 
        keys = np.random.choice(self.keys, size = self.batch_size) # randomly chooses n=batch_size number of patients
        for k in keys:
            try:
                i = np.random.choice(self.train_data[k], size=1)[0] # chooses some randomly images for kth patient
                img = get_img(f'./Dataset/train/{k}/{i}') # resizes ith image of kth patient
                x.append(img) # append kth patient's image data in the list x
                a.append(self.a[k]) # append kth patient's gradinet in the list a
                tab.append(self.tab[k]) # append kth patient's tabular data in the tab list
            except:
                print(k, i)
       
        x,a,tab = np.array(x), np.array(a), np.array(tab) # convert list to array
        #x = np.expand_dims(x, axis=-1) 
        return [x, tab] , a

# %% [markdown]
# ## Build the Model

# %%
def get_model(model, shape):
    models_dict = {
        'b0': efn.EfficientNetB0(input_shape=shape,weights='imagenet',include_top=False),
        'b1': efn.EfficientNetB1(input_shape=shape,weights=None,include_top=False),
        'b2': efn.EfficientNetB2(input_shape=shape,weights=None,include_top=False),
        'b3': efn.EfficientNetB3(input_shape=shape,weights='imagenet',include_top=False),
        'b4': efn.EfficientNetB4(input_shape=shape,weights='imagenet',include_top=False),
        'b5': efn.EfficientNetB5(input_shape=shape,weights=None,include_top=False),
        'b6': efn.EfficientNetB6(input_shape=shape,weights=None,include_top=False),
        'b7': efn.EfficientNetB7(input_shape=shape,weights=None,include_top=False),
        #'RNet50': resnet50.ResNet50(input_shape=shape,weights=None,include_top=False),
        #'V16': vgg16.VGG16(input_shape=shape,weights=None,include_top=False)
    }
    return models_dict[model]

def build_model(shape=(512, 512, 3), model_class=None):
    inp = Input(shape=shape)
    base = get_model(model_class, shape)
    x = base(inp)
    x = GlobalAveragePooling2D()(x)
    inp2 = Input(shape=(4,)) # indicates that the expected input will be batches of 4-dimensional vectors
    x2 = GaussianNoise(0.2)(inp2) # to mitigate overfitting
    x = Concatenate()([x, x2]) 
    x = Dropout(0.5)(x) 
    x = Dense(1)(x)
    model = Model([inp, inp2] , x)
    return model

# %%
MODEL_CLASS = 'b4'
base_model = build_model(shape=(512, 512, 3), model_class=MODEL_CLASS)
base_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  efficientnet-b4 (Functional)   (None, 16, 16, 1792  17673816    ['input_1[0][0]']
#                                 )
#
#  input_10 (InputLayer)          [(None, 4)]          0           []
#
#  global_average_pooling2d (Glob  (None, 1792)        0           ['efficientnet-b4[0][0]']
#  alAveragePooling2D)
#
#  gaussian_noise (GaussianNoise)  (None, 4)           0           ['input_10[0][0]']
#
#  concatenate (Concatenate)      (None, 1796)         0           ['global_average_pooling2d[0][0]'
#                                                                  , 'gaussian_noise[0][0]']
#
#  dropout (Dropout)              (None, 1796)         0           ['concatenate[0][0]']
#
#  dense (Dense)                  (None, 1)            1797        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 17,675,613
# Trainable params: 17,550,413
# Non-trainable params: 125,200
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile and Train the Model

# %%
BATCH_SIZE = 4
EPOCHS = 100
LR = 0.001
SAVE_BEST = True
tr_p, vl_p = train_test_split(P, shuffle=True, train_size= 0.8)

# %%
P = np.array(P)
subs = []
folds_history = []

"""
er = tf.keras.callbacks.EarlyStopping(monitor="val_loss",min_delta=1e-3,patience=15,verbose=1,mode="auto",baseline=None,
      restore_best_weights=True,) #Stop training when a monitored metric has stopped improving.
"""

cpt = tf.keras.callbacks.ModelCheckpoint(filepath=f'{MODEL_CLASS}_{EPOCHS}_epochs.h5',monitor='val_loss',verbose=1, 
    save_best_only=SAVE_BEST,mode='auto') #to save model or weights in a checkpoint file at lowest validation loss

rlp = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=5, verbose=1, min_lr=1e-8) 
     #Reduce learning rate when a metric has stopped improving.
     # if improvement stops, after 5 epochs learning rate will be reduced

model = build_model(model_class=MODEL_CLASS)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LR), loss="mae") 
history = model.fit(IGenerator(keys=tr_p, a = A, tab = TAB, batch_size=BATCH_SIZE), 
                    steps_per_epoch = 32,
                    validation_data=IGenerator(keys=P, a = A, tab = TAB, batch_size=BATCH_SIZE),
                    validation_steps = 32, 
                    callbacks = [cpt, rlp], 
                    epochs=EPOCHS)
folds_history.append(history.history)
print('Training Complete!!!')
# Out:
# Epoch 1/100
# 32/32 [==============================] - ETA: 0s - loss: 5.0393
# Epoch 1: val_loss improved from inf to 4.63134, saving model to b4_100_epochs.h5
# 32/32 [==============================] - 187s 5s/step - loss: 5.0393 - val_loss: 4.6313 - lr: 0.0010
# Epoch 2/100
# 32/32 [==============================] - ETA: 0s - loss: 4.5791
# Epoch 2: val_loss did not improve from 4.63134
# 32/32 [==============================] - 157s 5s/step - loss: 4.5791 - val_loss: 11.8019 - lr: 0.0010
# Epoch 3/100
# 32/32 [==============================] - ETA: 0s - loss: 4.7281
# Epoch 3: val_loss did not improve from 4.63134
# 32/32 [==============================] - 156s 5s/step - loss: 4.7281 - val_loss: 5.6984 - lr: 0.0010
# Epoch 4/100
# 32/32 [==============================] - ETA: 0s - loss: 4.5739
# Epoch 4: val_loss improved from 4.63134 to 4.36588, saving model to b4_100_epochs.h5
# 32/32 [==============================] - 157s 5s/step - loss: 4.5739 - val_loss: 4.3659 - lr: 0.0010
# Epoch 5/100
# 32/32 [==============================] - ETA: 0s - loss: 4.7292
# Epoch 5: val_loss did not improve from 4.36588
# 32/32 [==============================] - 156s 5s/step - loss: 4.7292 - val_loss: 4.4904 - lr: 0.0010
# Epoch 6/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1431
# Epoch 6: val_loss did not improve from 4.36588
# 32/32 [==============================] - 156s 5s/step - loss: 4.1431 - val_loss: 5.1945 - lr: 0.0010
# Epoch 7/100
# 32/32 [==============================] - ETA: 0s - loss: 4.5953
# Epoch 7: val_loss did not improve from 4.36588
# 32/32 [==============================] - 155s 5s/step - loss: 4.5953 - val_loss: 4.9490 - lr: 0.0010
# Epoch 8/100
# 32/32 [==============================] - ETA: 0s - loss: 4.3124
# Epoch 8: val_loss did not improve from 4.36588
# 32/32 [==============================] - 156s 5s/step - loss: 4.3124 - val_loss: 4.9256 - lr: 0.0010
# Epoch 9/100
# 32/32 [==============================] - ETA: 0s - loss: 4.5443
# Epoch 9: val_loss improved from 4.36588 to 3.73769, saving model to b4_100_epochs.h5
# 32/32 [==============================] - 156s 5s/step - loss: 4.5443 - val_loss: 3.7377 - lr: 0.0010
# Epoch 10/100
# 32/32 [==============================] - ETA: 0s - loss: 4.4418
# Epoch 10: val_loss did not improve from 3.73769
# 32/32 [==============================] - 155s 5s/step - loss: 4.4418 - val_loss: 3.8782 - lr: 0.0010
# Epoch 11/100
# 32/32 [==============================] - ETA: 0s - loss: 3.9399
# Epoch 11: val_loss did not improve from 3.73769
# 32/32 [==============================] - 155s 5s/step - loss: 3.9399 - val_loss: 4.4732 - lr: 0.0010
# Epoch 12/100
# 32/32 [==============================] - ETA: 0s - loss: 3.9052
# Epoch 12: val_loss did not improve from 3.73769
# 32/32 [==============================] - 155s 5s/step - loss: 3.9052 - val_loss: 4.4574 - lr: 0.0010
# Epoch 13/100
# 32/32 [==============================] - ETA: 0s - loss: 4.2167
# Epoch 13: val_loss did not improve from 3.73769
# 32/32 [==============================] - 155s 5s/step - loss: 4.2167 - val_loss: 4.0428 - lr: 0.0010
# Epoch 14/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1960
# Epoch 14: val_loss did not improve from 3.73769
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 [==============================] - 155s 5s/step - loss: 4.1960 - val_loss: 6.9682 - lr: 0.0010
# Epoch 15/100
# 32/32 [==============================] - ETA: 0s - loss: 4.7607
# Epoch 15: val_loss did not improve from 3.73769
# 32/32 [==============================] - 154s 5s/step - loss: 4.7607 - val_loss: 4.3902 - lr: 5.0000e-04
# Epoch 16/100
# 32/32 [==============================] - ETA: 0s - loss: 4.9193
# Epoch 16: val_loss did not improve from 3.73769
# 32/32 [==============================] - 154s 5s/step - loss: 4.9193 - val_loss: 4.9094 - lr: 5.0000e-04
# Epoch 17/100
# 32/32 [==============================] - ETA: 0s - loss: 4.4528
# Epoch 17: val_loss did not improve from 3.73769
# 32/32 [==============================] - 154s 5s/step - loss: 4.4528 - val_loss: 4.3040 - lr: 5.0000e-04
# Epoch 18/100
# 32/32 [==============================] - ETA: 0s - loss: 4.3939
# Epoch 18: val_loss did not improve from 3.73769
# 32/32 [==============================] - 154s 5s/step - loss: 4.3939 - val_loss: 4.6122 - lr: 5.0000e-04
# Epoch 19/100
# 32/32 [==============================] - ETA: 0s - loss: 3.9856
# Epoch 19: val_loss did not improve from 3.73769
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 [==============================] - 154s 5s/step - loss: 3.9856 - val_loss: 4.8394 - lr: 5.0000e-04
# Epoch 20/100
# 32/32 [==============================] - ETA: 0s - loss: 4.7993
# Epoch 20: val_loss did not improve from 3.73769
# 32/32 [==============================] - 154s 5s/step - loss: 4.7993 - val_loss: 3.8281 - lr: 2.5000e-04
# Epoch 21/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1396
# Epoch 21: val_loss did not improve from 3.73769
# 32/32 [==============================] - 154s 5s/step - loss: 4.1396 - val_loss: 3.9175 - lr: 2.5000e-04
# Epoch 22/100
# 32/32 [==============================] - ETA: 0s - loss: 3.6794
# Epoch 22: val_loss did not improve from 3.73769
# 32/32 [==============================] - 154s 5s/step - loss: 3.6794 - val_loss: 4.3069 - lr: 2.5000e-04
# Epoch 23/100
# 32/32 [==============================] - ETA: 0s - loss: 4.7936
# Epoch 23: val_loss did not improve from 3.73769
# 32/32 [==============================] - 154s 5s/step - loss: 4.7936 - val_loss: 4.5736 - lr: 2.5000e-04
# Epoch 24/100
# 32/32 [==============================] - ETA: 0s - loss: 4.4672
# Epoch 24: val_loss did not improve from 3.73769
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 32/32 [==============================] - 155s 5s/step - loss: 4.4672 - val_loss: 3.7845 - lr: 2.5000e-04
# Epoch 25/100
# 32/32 [==============================] - ETA: 0s - loss: 4.4568
# Epoch 25: val_loss improved from 3.73769 to 3.65872, saving model to b4_100_epochs.h5
# 32/32 [==============================] - 155s 5s/step - loss: 4.4568 - val_loss: 3.6587 - lr: 1.2500e-04
# Epoch 26/100
# 32/32 [==============================] - ETA: 0s - loss: 4.8994
# Epoch 26: val_loss did not improve from 3.65872
# 32/32 [==============================] - 155s 5s/step - loss: 4.8994 - val_loss: 4.3866 - lr: 1.2500e-04
# Epoch 27/100
# 32/32 [==============================] - ETA: 0s - loss: 5.0841
# Epoch 27: val_loss did not improve from 3.65872
# 32/32 [==============================] - 155s 5s/step - loss: 5.0841 - val_loss: 4.2162 - lr: 1.2500e-04
# Epoch 28/100
# 32/32 [==============================] - ETA: 0s - loss: 3.8452
# Epoch 28: val_loss improved from 3.65872 to 3.48326, saving model to b4_100_epochs.h5
# 32/32 [==============================] - 155s 5s/step - loss: 3.8452 - val_loss: 3.4833 - lr: 1.2500e-04
# Epoch 29/100
# 32/32 [==============================] - ETA: 0s - loss: 4.2143
# Epoch 29: val_loss did not improve from 3.48326
# 32/32 [==============================] - 155s 5s/step - loss: 4.2143 - val_loss: 4.2840 - lr: 1.2500e-04
# Epoch 30/100
# 32/32 [==============================] - ETA: 0s - loss: 3.8137
# Epoch 30: val_loss did not improve from 3.48326
# 32/32 [==============================] - 155s 5s/step - loss: 3.8137 - val_loss: 4.7170 - lr: 1.2500e-04
# Epoch 31/100
# 32/32 [==============================] - ETA: 0s - loss: 4.9191
# Epoch 31: val_loss did not improve from 3.48326
# 32/32 [==============================] - 155s 5s/step - loss: 4.9191 - val_loss: 4.5257 - lr: 1.2500e-04
# Epoch 32/100
# 32/32 [==============================] - ETA: 0s - loss: 4.5722
# Epoch 32: val_loss did not improve from 3.48326
# 32/32 [==============================] - 156s 5s/step - loss: 4.5722 - val_loss: 4.1466 - lr: 1.2500e-04
# Epoch 33/100
# 32/32 [==============================] - ETA: 0s - loss: 4.5696
# Epoch 33: val_loss did not improve from 3.48326
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 32/32 [==============================] - 158s 5s/step - loss: 4.5696 - val_loss: 4.2236 - lr: 1.2500e-04
# Epoch 34/100
# 32/32 [==============================] - ETA: 0s - loss: 4.9302
# Epoch 34: val_loss did not improve from 3.48326
# 32/32 [==============================] - 159s 5s/step - loss: 4.9302 - val_loss: 4.5651 - lr: 6.2500e-05
# Epoch 35/100
# 32/32 [==============================] - ETA: 0s - loss: 5.0102
# Epoch 35: val_loss did not improve from 3.48326
# 32/32 [==============================] - 158s 5s/step - loss: 5.0102 - val_loss: 4.6487 - lr: 6.2500e-05
# Epoch 36/100
# 32/32 [==============================] - ETA: 0s - loss: 3.7159
# Epoch 36: val_loss did not improve from 3.48326
# 32/32 [==============================] - 158s 5s/step - loss: 3.7159 - val_loss: 3.9415 - lr: 6.2500e-05
# Epoch 37/100
# 32/32 [==============================] - ETA: 0s - loss: 3.8797
# Epoch 37: val_loss did not improve from 3.48326
# 32/32 [==============================] - 158s 5s/step - loss: 3.8797 - val_loss: 4.4430 - lr: 6.2500e-05
# Epoch 38/100
# 32/32 [==============================] - ETA: 0s - loss: 3.6306
# Epoch 38: val_loss did not improve from 3.48326
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 32/32 [==============================] - 158s 5s/step - loss: 3.6306 - val_loss: 4.1424 - lr: 6.2500e-05
# Epoch 39/100
# 32/32 [==============================] - ETA: 0s - loss: 3.5652
# Epoch 39: val_loss did not improve from 3.48326
# 32/32 [==============================] - 158s 5s/step - loss: 3.5652 - val_loss: 4.8871 - lr: 3.1250e-05
# Epoch 40/100
# 32/32 [==============================] - ETA: 0s - loss: 4.6918
# Epoch 40: val_loss did not improve from 3.48326
# 32/32 [==============================] - 159s 5s/step - loss: 4.6918 - val_loss: 4.4880 - lr: 3.1250e-05
# Epoch 41/100
# 32/32 [==============================] - ETA: 0s - loss: 4.5142
# Epoch 41: val_loss did not improve from 3.48326
# 32/32 [==============================] - 159s 5s/step - loss: 4.5142 - val_loss: 4.0525 - lr: 3.1250e-05
# Epoch 42/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1727
# Epoch 42: val_loss did not improve from 3.48326
# 32/32 [==============================] - 159s 5s/step - loss: 4.1727 - val_loss: 4.0792 - lr: 3.1250e-05
# Epoch 43/100
# 32/32 [==============================] - ETA: 0s - loss: 4.3479
# Epoch 43: val_loss did not improve from 3.48326
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 32/32 [==============================] - 159s 5s/step - loss: 4.3479 - val_loss: 4.3083 - lr: 3.1250e-05
# Epoch 44/100
# 32/32 [==============================] - ETA: 0s - loss: 3.7664
# Epoch 44: val_loss did not improve from 3.48326
# 32/32 [==============================] - 160s 5s/step - loss: 3.7664 - val_loss: 4.3570 - lr: 1.5625e-05
# Epoch 45/100
# 32/32 [==============================] - ETA: 0s - loss: 4.4078
# Epoch 45: val_loss did not improve from 3.48326
# 32/32 [==============================] - 160s 5s/step - loss: 4.4078 - val_loss: 4.3822 - lr: 1.5625e-05
# Epoch 46/100
# 32/32 [==============================] - ETA: 0s - loss: 4.6791
# Epoch 46: val_loss did not improve from 3.48326
# 32/32 [==============================] - 161s 5s/step - loss: 4.6791 - val_loss: 3.9898 - lr: 1.5625e-05
# Epoch 47/100
# 32/32 [==============================] - ETA: 0s - loss: 3.8189
# Epoch 47: val_loss improved from 3.48326 to 3.22398, saving model to b4_100_epochs.h5
# 32/32 [==============================] - 162s 5s/step - loss: 3.8189 - val_loss: 3.2240 - lr: 1.5625e-05
# Epoch 48/100
# 32/32 [==============================] - ETA: 0s - loss: 4.4226
# Epoch 48: val_loss did not improve from 3.22398
# 32/32 [==============================] - 161s 5s/step - loss: 4.4226 - val_loss: 3.9957 - lr: 1.5625e-05
# Epoch 49/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1899
# Epoch 49: val_loss did not improve from 3.22398
# 32/32 [==============================] - 161s 5s/step - loss: 4.1899 - val_loss: 3.9144 - lr: 1.5625e-05
# Epoch 50/100
# 32/32 [==============================] - ETA: 0s - loss: 4.2028
# Epoch 50: val_loss did not improve from 3.22398
# 32/32 [==============================] - 161s 5s/step - loss: 4.2028 - val_loss: 4.5688 - lr: 1.5625e-05
# Epoch 51/100
# 32/32 [==============================] - ETA: 0s - loss: 4.2361
# Epoch 51: val_loss did not improve from 3.22398
# 32/32 [==============================] - 161s 5s/step - loss: 4.2361 - val_loss: 3.4565 - lr: 1.5625e-05
# Epoch 52/100
# 32/32 [==============================] - ETA: 0s - loss: 3.5893
# Epoch 52: val_loss did not improve from 3.22398
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 32/32 [==============================] - 161s 5s/step - loss: 3.5893 - val_loss: 4.5394 - lr: 1.5625e-05
# Epoch 53/100
# 32/32 [==============================] - ETA: 0s - loss: 4.4852
# Epoch 53: val_loss did not improve from 3.22398
# 32/32 [==============================] - 161s 5s/step - loss: 4.4852 - val_loss: 3.7394 - lr: 7.8125e-06
# Epoch 54/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1618
# Epoch 54: val_loss did not improve from 3.22398
# 32/32 [==============================] - 162s 5s/step - loss: 4.1618 - val_loss: 4.3317 - lr: 7.8125e-06
# Epoch 55/100
# 32/32 [==============================] - ETA: 0s - loss: 3.8027
# Epoch 55: val_loss did not improve from 3.22398
# 32/32 [==============================] - 161s 5s/step - loss: 3.8027 - val_loss: 4.4720 - lr: 7.8125e-06
# Epoch 56/100
# 32/32 [==============================] - ETA: 0s - loss: 4.0714
# Epoch 56: val_loss did not improve from 3.22398
# 32/32 [==============================] - 162s 5s/step - loss: 4.0714 - val_loss: 3.9784 - lr: 7.8125e-06
# Epoch 57/100
# 32/32 [==============================] - ETA: 0s - loss: 4.3234
# Epoch 57: val_loss did not improve from 3.22398
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 32/32 [==============================] - 162s 5s/step - loss: 4.3234 - val_loss: 4.4181 - lr: 7.8125e-06
# Epoch 58/100
# 32/32 [==============================] - ETA: 0s - loss: 3.3759
# Epoch 58: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 3.3759 - val_loss: 4.1909 - lr: 3.9063e-06
# Epoch 59/100
# 32/32 [==============================] - ETA: 0s - loss: 4.5587
# Epoch 59: val_loss did not improve from 3.22398
# 32/32 [==============================] - 162s 5s/step - loss: 4.5587 - val_loss: 4.1550 - lr: 3.9063e-06
# Epoch 60/100
# 32/32 [==============================] - ETA: 0s - loss: 4.4479
# Epoch 60: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 4.4479 - val_loss: 4.3387 - lr: 3.9063e-06
# Epoch 61/100
# 32/32 [==============================] - ETA: 0s - loss: 4.3673
# Epoch 61: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 4.3673 - val_loss: 4.4189 - lr: 3.9063e-06
# Epoch 62/100
# 32/32 [==============================] - ETA: 0s - loss: 4.3400
# Epoch 62: val_loss did not improve from 3.22398
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 32/32 [==============================] - 163s 5s/step - loss: 4.3400 - val_loss: 3.6538 - lr: 3.9063e-06
# Epoch 63/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1797
# Epoch 63: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 4.1797 - val_loss: 3.6783 - lr: 1.9531e-06
# Epoch 64/100
# 32/32 [==============================] - ETA: 0s - loss: 4.0984
# Epoch 64: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 4.0984 - val_loss: 4.3641 - lr: 1.9531e-06
# Epoch 65/100
# 32/32 [==============================] - ETA: 0s - loss: 3.6383
# Epoch 65: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 3.6383 - val_loss: 4.6688 - lr: 1.9531e-06
# Epoch 66/100
# 32/32 [==============================] - ETA: 0s - loss: 4.4681
# Epoch 66: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 4.4681 - val_loss: 4.2344 - lr: 1.9531e-06
# Epoch 67/100
# 32/32 [==============================] - ETA: 0s - loss: 4.6298
# Epoch 67: val_loss did not improve from 3.22398
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 32/32 [==============================] - 163s 5s/step - loss: 4.6298 - val_loss: 3.7246 - lr: 1.9531e-06
# Epoch 68/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1861
# Epoch 68: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 4.1861 - val_loss: 4.3268 - lr: 9.7656e-07
# Epoch 69/100
# 32/32 [==============================] - ETA: 0s - loss: 3.6310
# Epoch 69: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 3.6310 - val_loss: 4.1316 - lr: 9.7656e-07
# Epoch 70/100
# 32/32 [==============================] - ETA: 0s - loss: 4.0967
# Epoch 70: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 4.0967 - val_loss: 4.0496 - lr: 9.7656e-07
# Epoch 71/100
# 32/32 [==============================] - ETA: 0s - loss: 4.3284
# Epoch 71: val_loss did not improve from 3.22398
# 32/32 [==============================] - 163s 5s/step - loss: 4.3284 - val_loss: 3.7323 - lr: 9.7656e-07
# Epoch 72/100
# 32/32 [==============================] - ETA: 0s - loss: 4.7472
# Epoch 72: val_loss did not improve from 3.22398
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 32/32 [==============================] - 164s 5s/step - loss: 4.7472 - val_loss: 4.2080 - lr: 9.7656e-07
# Epoch 73/100
# 32/32 [==============================] - ETA: 0s - loss: 4.0212
# Epoch 73: val_loss did not improve from 3.22398
# 32/32 [==============================] - 164s 5s/step - loss: 4.0212 - val_loss: 4.2741 - lr: 4.8828e-07
# Epoch 74/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1562
# Epoch 74: val_loss did not improve from 3.22398
# 32/32 [==============================] - 165s 5s/step - loss: 4.1562 - val_loss: 4.4191 - lr: 4.8828e-07
# Epoch 75/100
# 32/32 [==============================] - ETA: 0s - loss: 3.9500
# Epoch 75: val_loss did not improve from 3.22398
# 32/32 [==============================] - 164s 5s/step - loss: 3.9500 - val_loss: 4.1431 - lr: 4.8828e-07
# Epoch 76/100
# 32/32 [==============================] - ETA: 0s - loss: 4.6689
# Epoch 76: val_loss did not improve from 3.22398
# 32/32 [==============================] - 165s 5s/step - loss: 4.6689 - val_loss: 3.6030 - lr: 4.8828e-07
# Epoch 77/100
# 32/32 [==============================] - ETA: 0s - loss: 4.7824
# Epoch 77: val_loss did not improve from 3.22398
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 32/32 [==============================] - 165s 5s/step - loss: 4.7824 - val_loss: 3.6721 - lr: 4.8828e-07
# Epoch 78/100
# 32/32 [==============================] - ETA: 0s - loss: 3.7450
# Epoch 78: val_loss did not improve from 3.22398
# 32/32 [==============================] - 165s 5s/step - loss: 3.7450 - val_loss: 4.5391 - lr: 2.4414e-07
# Epoch 79/100
# 32/32 [==============================] - ETA: 0s - loss: 4.5153
# Epoch 79: val_loss did not improve from 3.22398
# 32/32 [==============================] - 166s 5s/step - loss: 4.5153 - val_loss: 3.9788 - lr: 2.4414e-07
# Epoch 80/100
# 32/32 [==============================] - ETA: 0s - loss: 4.2378
# Epoch 80: val_loss did not improve from 3.22398
# 32/32 [==============================] - 165s 5s/step - loss: 4.2378 - val_loss: 4.1796 - lr: 2.4414e-07
# Epoch 81/100
# 32/32 [==============================] - ETA: 0s - loss: 4.0979
# Epoch 81: val_loss did not improve from 3.22398
# 32/32 [==============================] - 165s 5s/step - loss: 4.0979 - val_loss: 4.1908 - lr: 2.4414e-07
# Epoch 82/100
# 32/32 [==============================] - ETA: 0s - loss: 4.2114
# Epoch 82: val_loss did not improve from 3.22398
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 32/32 [==============================] - 165s 5s/step - loss: 4.2114 - val_loss: 3.7079 - lr: 2.4414e-07
# Epoch 83/100
# 32/32 [==============================] - ETA: 0s - loss: 4.8151
# Epoch 83: val_loss did not improve from 3.22398
# 32/32 [==============================] - 166s 5s/step - loss: 4.8151 - val_loss: 4.9401 - lr: 1.2207e-07
# Epoch 84/100
# 32/32 [==============================] - ETA: 0s - loss: 3.9249
# Epoch 84: val_loss did not improve from 3.22398
# 32/32 [==============================] - 165s 5s/step - loss: 3.9249 - val_loss: 4.4195 - lr: 1.2207e-07
# Epoch 85/100
# 32/32 [==============================] - ETA: 0s - loss: 4.0123
# Epoch 85: val_loss did not improve from 3.22398
# 32/32 [==============================] - 165s 5s/step - loss: 4.0123 - val_loss: 3.9418 - lr: 1.2207e-07
# Epoch 86/100
# 32/32 [==============================] - ETA: 0s - loss: 4.5934
# Epoch 86: val_loss did not improve from 3.22398
# 32/32 [==============================] - 165s 5s/step - loss: 4.5934 - val_loss: 4.3548 - lr: 1.2207e-07
# Epoch 87/100
# 32/32 [==============================] - ETA: 0s - loss: 4.2308
# Epoch 87: val_loss did not improve from 3.22398
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 32/32 [==============================] - 166s 5s/step - loss: 4.2308 - val_loss: 3.2858 - lr: 1.2207e-07
# Epoch 88/100
# 32/32 [==============================] - ETA: 0s - loss: 4.3091
# Epoch 88: val_loss did not improve from 3.22398
# 32/32 [==============================] - 166s 5s/step - loss: 4.3091 - val_loss: 3.7099 - lr: 6.1035e-08
# Epoch 89/100
# 32/32 [==============================] - ETA: 0s - loss: 4.0861
# Epoch 89: val_loss did not improve from 3.22398
# 32/32 [==============================] - 166s 5s/step - loss: 4.0861 - val_loss: 3.9015 - lr: 6.1035e-08
# Epoch 90/100
# 32/32 [==============================] - ETA: 0s - loss: 4.3197
# Epoch 90: val_loss did not improve from 3.22398
# 32/32 [==============================] - 166s 5s/step - loss: 4.3197 - val_loss: 4.5082 - lr: 6.1035e-08
# Epoch 91/100
# 32/32 [==============================] - ETA: 0s - loss: 5.0192
# Epoch 91: val_loss did not improve from 3.22398
# 32/32 [==============================] - 166s 5s/step - loss: 5.0192 - val_loss: 3.8554 - lr: 6.1035e-08
# Epoch 92/100
# 32/32 [==============================] - ETA: 0s - loss: 4.9570
# Epoch 92: val_loss did not improve from 3.22398
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 32/32 [==============================] - 167s 5s/step - loss: 4.9570 - val_loss: 3.8997 - lr: 6.1035e-08
# Epoch 93/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1809
# Epoch 93: val_loss did not improve from 3.22398
# 32/32 [==============================] - 167s 5s/step - loss: 4.1809 - val_loss: 4.7513 - lr: 3.0518e-08
# Epoch 94/100
# 32/32 [==============================] - ETA: 0s - loss: 4.3511
# Epoch 94: val_loss did not improve from 3.22398
# 32/32 [==============================] - 167s 5s/step - loss: 4.3511 - val_loss: 3.4988 - lr: 3.0518e-08
# Epoch 95/100
# 32/32 [==============================] - ETA: 0s - loss: 3.9857
# Epoch 95: val_loss did not improve from 3.22398
# 32/32 [==============================] - 168s 5s/step - loss: 3.9857 - val_loss: 3.6596 - lr: 3.0518e-08
# Epoch 96/100
# 32/32 [==============================] - ETA: 0s - loss: 4.2322
# Epoch 96: val_loss did not improve from 3.22398
# 32/32 [==============================] - 167s 5s/step - loss: 4.2322 - val_loss: 4.1444 - lr: 3.0518e-08
# Epoch 97/100
# 32/32 [==============================] - ETA: 0s - loss: 4.0127
# Epoch 97: val_loss did not improve from 3.22398
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 32/32 [==============================] - 168s 5s/step - loss: 4.0127 - val_loss: 4.1238 - lr: 3.0518e-08
# Epoch 98/100
# 32/32 [==============================] - ETA: 0s - loss: 4.6724
# Epoch 98: val_loss did not improve from 3.22398
# 32/32 [==============================] - 169s 5s/step - loss: 4.6724 - val_loss: 3.8354 - lr: 1.5259e-08
# Epoch 99/100
# 32/32 [==============================] - ETA: 0s - loss: 3.9726
# Epoch 99: val_loss did not improve from 3.22398
# 32/32 [==============================] - 169s 5s/step - loss: 3.9726 - val_loss: 3.7749 - lr: 1.5259e-08
# Epoch 100/100
# 32/32 [==============================] - ETA: 0s - loss: 4.1240
# Epoch 100: val_loss did not improve from 3.22398
# 32/32 [==============================] - 170s 5s/step - loss: 4.1240 - val_loss: 3.8807 - lr: 1.5259e-08
# Training Complete!!!

# %% [markdown]
# # Save Model History

# %%
# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# save to json:  
hist_json_file = './Saved_Models/EffNet_b4_history_100_epoch_imagenet.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv: 
hist_csv_file = './Saved_Models/EffNet_b4_history_100_epoch_imagenet.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %% [markdown]
# # Visualize Training Results

# %%
result_dir = './Dataset/train/B4'
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(EPOCHS)

# %%
plt.plot(epochs_range, loss, 'b4', label='Training Loss')
plt.plot(epochs_range, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.savefig(result_dir + 'b4_100_epoch_loss_imagenet.png')
plt.savefig(result_dir + 'b4_100_epoch_loss_imagenet.pdf', dpi=150)
tikzplotlib.save(result_dir + 'b4_100_epoch_loss_imagenet.tex')
plt.show()

# %%
def smooth_curve(points, factor=0.85):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
epochs_range = range(20,EPOCHS)
plt.plot(epochs_range,
         smooth_curve(loss[20:]), 'b4', label='Training loss')
plt.plot(epochs_range,
         smooth_curve(val_loss[20:]), 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()


plt.savefig(result_dir + 'b4_100_epoch_loss_smooth_imagenet.png')
plt.savefig(result_dir + 'b4_100_epoch_loss_smooth_imagenet.pdf', dpi=150)
tikzplotlib.save(result_dir + 'b4_100_epoch_loss_smooth_imagenet.tex')

plt.show()

# %%
def score(fvc_true, fvc_pred, sigma):
    sigma_clip = np.maximum(sigma, 70)
    delta = np.abs(fvc_true - fvc_pred)
    delta = np.minimum(delta, 1000)
    sq2 = np.sqrt(2)
    metric = (delta / sigma_clip)*sq2 + np.log(sigma_clip* sq2)
    return np.mean(metric)

# %%
metric = []
for q in tqdm(range(1, 10)):
    m = []
    for p in vl_p:
        x = [] 
        tab = [] 
        
        if p in ['ID00011637202177653955184', 'ID00052637202186188008618']:
            continue
        for i in os.listdir(f'./Dataset/train/{p}/'):
            x.append(get_img(f'./Dataset/train/{p}/{i}')) 
            tab.append(get_tab(train.loc[train.Patient == p, :])) 
        tab = np.array(tab) 
    
        x = np.expand_dims(x, axis=-1) 
        _a = model.predict([x, tab]) 
        a = np.quantile(_a, q / 10)
        
        percent_true = train.Percent.values[train.Patient == p]
        fvc_true = train.FVC.values[train.Patient == p]
        weeks_true = train.Weeks.values[train.Patient == p]
        
        fvc = a * (weeks_true - weeks_true[0]) + fvc_true[0]
        percent = percent_true[0] - a * abs(weeks_true - weeks_true[0])
        m.append(score(fvc_true, fvc, percent))
    print(np.mean(m))
    metric.append(np.mean(m))
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# 15/15 [==============================] - 97s 6s/step
# 10/10 [==============================] - 68s 7s/step
# 1/1 [==============================] - 6s 6s/step
# 10/10 [==============================] - 69s 7s/step
# 11/11 [==============================] - 66s 6s/step
# 19/19 [==============================] - 115s 6s/step
# 10/10 [==============================] - 61s 6s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 23s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 6s 6s/step
# 9/9 [==============================] - 52s 6s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 2/2 [==============================] - 11s 4s/step
# 10/10 [==============================] - 72s 7s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 3s 3s/step
# 14/14 [==============================] - 93s 7s/step
# 14/14 [==============================] - 98s 7s/step
# 15/15 [==============================] - 93s 6s/step
# 2/2 [==============================] - 11s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 3/3 [==============================] - 16s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 13/13 [==============================] - 74s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 10/10 [==============================] - 62s 6s/step
# 2/2 [==============================] - 10s 4s/step
# 1/1 [==============================] - 6s 6s/step
# 7/7 [==============================] - 44s 6s/step
# 8/8 [==============================] - 54s 7s/step
# 2/2 [==============================] - 14s 7s/step
# 6.454966284445615
# 15/15 [==============================] - 108s 7s/step
# 10/10 [==============================] - 68s 7s/step
# 1/1 [==============================] - 5s 5s/step
# 10/10 [==============================] - 59s 6s/step
# 11/11 [==============================] - 76s 7s/step
# 19/19 [==============================] - 121s 6s/step
# 10/10 [==============================] - 65s 6s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 19s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 5s 5s/step
# 9/9 [==============================] - 52s 6s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 2/2 [==============================] - 10s 4s/step
# 10/10 [==============================] - 67s 7s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 14/14 [==============================] - 83s 6s/step
# 14/14 [==============================] - 98s 7s/step
# 15/15 [==============================] - 102s 7s/step
# 2/2 [==============================] - 11s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 3/3 [==============================] - 16s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 13/13 [==============================] - 72s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 10/10 [==============================] - 62s 6s/step
# 2/2 [==============================] - 10s 4s/step
# 1/1 [==============================] - 6s 6s/step
# 7/7 [==============================] - 42s 6s/step
# 8/8 [==============================] - 54s 7s/step
# 2/2 [==============================] - 14s 7s/step
# 6.455885927222565
# 15/15 [==============================] - 89s 6s/step
# 10/10 [==============================] - 55s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 10/10 [==============================] - 59s 6s/step
# 11/11 [==============================] - 71s 6s/step
# 19/19 [==============================] - 111s 6s/step
# 10/10 [==============================] - 63s 6s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 6s 6s/step
# 4/4 [==============================] - 19s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 5s 5s/step
# 9/9 [==============================] - 52s 6s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 2/2 [==============================] - 10s 4s/step
# 10/10 [==============================] - 62s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 14/14 [==============================] - 82s 6s/step
# 14/14 [==============================] - 86s 6s/step
# 15/15 [==============================] - 102s 7s/step
# 2/2 [==============================] - 11s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 3/3 [==============================] - 16s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 13/13 [==============================] - 76s 6s/step
# 1/1 [==============================] - 4s 4s/step
# 10/10 [==============================] - 63s 6s/step
# 2/2 [==============================] - 10s 4s/step
# 1/1 [==============================] - 6s 6s/step
# 7/7 [==============================] - 44s 6s/step
# 8/8 [==============================] - 54s 7s/step
# 2/2 [==============================] - 14s 7s/step
# 6.4559122452303495
# 15/15 [==============================] - 86s 6s/step
# 10/10 [==============================] - 59s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 10/10 [==============================] - 59s 6s/step
# 11/11 [==============================] - 71s 6s/step
# 19/19 [==============================] - 110s 6s/step
# 10/10 [==============================] - 57s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 4/4 [==============================] - 19s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 5s 5s/step
# 9/9 [==============================] - 48s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 2/2 [==============================] - 10s 4s/step
# 10/10 [==============================] - 58s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 14/14 [==============================] - 82s 6s/step
# 14/14 [==============================] - 83s 6s/step
# 15/15 [==============================] - 94s 6s/step
# 2/2 [==============================] - 10s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 3/3 [==============================] - 16s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 13/13 [==============================] - 76s 6s/step
# 1/1 [==============================] - 4s 4s/step
# 10/10 [==============================] - 62s 6s/step
# 2/2 [==============================] - 9s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 7/7 [==============================] - 42s 6s/step
# 8/8 [==============================] - 48s 6s/step
# 2/2 [==============================] - 13s 6s/step
# 6.456026362249034
# 15/15 [==============================] - 92s 6s/step
# 10/10 [==============================] - 59s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 10/10 [==============================] - 59s 6s/step
# 11/11 [==============================] - 77s 7s/step
# 19/19 [==============================] - 111s 6s/step
# 10/10 [==============================] - 56s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 4/4 [==============================] - 19s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 5s 5s/step
# 9/9 [==============================] - 48s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 2/2 [==============================] - 10s 4s/step
# 10/10 [==============================] - 58s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 14/14 [==============================] - 82s 6s/step
# 14/14 [==============================] - 83s 6s/step
# 15/15 [==============================] - 86s 6s/step
# 2/2 [==============================] - 9s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 3/3 [==============================] - 14s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 13/13 [==============================] - 73s 6s/step
# 1/1 [==============================] - 4s 4s/step
# 10/10 [==============================] - 61s 6s/step
# 2/2 [==============================] - 9s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 7/7 [==============================] - 40s 6s/step
# 8/8 [==============================] - 48s 6s/step
# 2/2 [==============================] - 11s 5s/step
# 6.452759357322836
# 15/15 [==============================] - 92s 6s/step
# 10/10 [==============================] - 58s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 10/10 [==============================] - 59s 6s/step
# 11/11 [==============================] - 69s 6s/step
# 19/19 [==============================] - 113s 6s/step
# 10/10 [==============================] - 66s 6s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 4/4 [==============================] - 19s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 6s 6s/step
# 9/9 [==============================] - 48s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 2/2 [==============================] - 10s 4s/step
# 10/10 [==============================] - 58s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 14/14 [==============================] - 83s 6s/step
# 14/14 [==============================] - 84s 6s/step
# 15/15 [==============================] - 93s 6s/step
# 2/2 [==============================] - 11s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 3/3 [==============================] - 13s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 13/13 [==============================] - 74s 6s/step
# 1/1 [==============================] - 4s 4s/step
# 10/10 [==============================] - 62s 6s/step
# 2/2 [==============================] - 9s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 7/7 [==============================] - 42s 6s/step
# 8/8 [==============================] - 48s 6s/step
# 2/2 [==============================] - 11s 5s/step
# 6.449850734228026
# 15/15 [==============================] - 91s 6s/step
# 10/10 [==============================] - 59s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 10/10 [==============================] - 59s 6s/step
# 11/11 [==============================] - 71s 6s/step
# 19/19 [==============================] - 121s 6s/step
# 10/10 [==============================] - 66s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 4/4 [==============================] - 19s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 5s 5s/step
# 9/9 [==============================] - 48s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 2/2 [==============================] - 10s 4s/step
# 10/10 [==============================] - 58s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 14/14 [==============================] - 83s 6s/step
# 14/14 [==============================] - 83s 6s/step
# 15/15 [==============================] - 99s 7s/step
# 2/2 [==============================] - 11s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 3/3 [==============================] - 13s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 13/13 [==============================] - 75s 6s/step
# 1/1 [==============================] - 4s 4s/step
# 10/10 [==============================] - 63s 6s/step
# 2/2 [==============================] - 10s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 7/7 [==============================] - 42s 6s/step
# 8/8 [==============================] - 44s 5s/step
# 2/2 [==============================] - 11s 5s/step
# 6.44798527903309
# 15/15 [==============================] - 92s 6s/step
# 10/10 [==============================] - 60s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 10/10 [==============================] - 60s 6s/step
# 11/11 [==============================] - 79s 7s/step
# 19/19 [==============================] - 114s 6s/step
# 10/10 [==============================] - 66s 7s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 4/4 [==============================] - 19s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 5s 5s/step
# 9/9 [==============================] - 49s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 2/2 [==============================] - 10s 4s/step
# 10/10 [==============================] - 59s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 14/14 [==============================] - 83s 6s/step
# 14/14 [==============================] - 85s 6s/step
# 15/15 [==============================] - 102s 7s/step
# 2/2 [==============================] - 11s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 3/3 [==============================] - 13s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 13/13 [==============================] - 77s 6s/step
# 1/1 [==============================] - 4s 4s/step
# 10/10 [==============================] - 63s 6s/step
# 2/2 [==============================] - 10s 4s/step
# 1/1 [==============================] - 6s 6s/step
# 7/7 [==============================] - 38s 5s/step
# 8/8 [==============================] - 44s 5s/step
# 2/2 [==============================] - 11s 5s/step
# 6.459703076002573
# 15/15 [==============================] - 92s 6s/step
# 10/10 [==============================] - 59s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 10/10 [==============================] - 69s 7s/step
# 11/11 [==============================] - 79s 7s/step
# 19/19 [==============================] - 113s 6s/step
# 10/10 [==============================] - 53s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 4/4 [==============================] - 19s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 5s 5s/step
# 9/9 [==============================] - 52s 6s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 2/2 [==============================] - 10s 4s/step
# 10/10 [==============================] - 69s 7s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 14/14 [==============================] - 95s 7s/step
# 14/14 [==============================] - 95s 7s/step
# 15/15 [==============================] - 86s 6s/step
# 2/2 [==============================] - 9s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 3/3 [==============================] - 13s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 13/13 [==============================] - 77s 6s/step
# 1/1 [==============================] - 4s 4s/step
# 10/10 [==============================] - 68s 7s/step
# 2/2 [==============================] - 11s 4s/step
# 1/1 [==============================] - 6s 6s/step
# 7/7 [==============================] - 40s 6s/step
# 8/8 [==============================] - 48s 6s/step
# 2/2 [==============================] - 12s 6s/step
# 6.472051203668927

# %%
q = (np.argmin(metric) + 1)/ 2
q
# Out:
# 3.5

# %%
sub = pd.read_csv('./Dataset/sample_submission.csv') 
sub.head()
# Out:
#                     Patient_Week   FVC  Confidence
# 0  ID00419637202311204720264_-12  2000         100
# 1  ID00421637202311550012437_-12  2000         100
# 2  ID00422637202311677017371_-12  2000         100
# 3  ID00423637202312137826377_-12  2000         100
# 4  ID00426637202313170790466_-12  2000         100

# %%
test = pd.read_csv('./Dataset/test.csv') 
test
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00419637202311204720264      6  3020  70.186855   73  Male     Ex-smoker
# 1  ID00421637202311550012437     15  2739  82.045291   68  Male     Ex-smoker
# 2  ID00422637202311677017371      6  1930  76.672493   73  Male     Ex-smoker
# 3  ID00423637202312137826377     17  3294  79.258903   72  Male     Ex-smoker
# 4  ID00426637202313170790466      0  2925  71.824968   73  Male  Never smoked

# %%
A_test, B_test, P_test, W, FVC, STD, WEEK = {},{},{},{},{},{},{} 

for p in test.Patient.unique():
    x = [] 
    tab = [] 
    for i in os.listdir(f'./Dataset//test/{p}/'):
        x.append(get_img(f'./Dataset//test/{p}/{i}')) 
        tab.append(get_tab(test.loc[test.Patient == p, :])) 
    tab = np.array(tab) 
            
    x = np.expand_dims(x, axis=-1) 
    _a = model.predict([x, tab]) 
    a = np.quantile(0, 1)
    A_test[p] = a
    B_test[p] = test.FVC.values[test.Patient == p] - a*test.Weeks.values[test.Patient == p]
    P_test[p] = test.Percent.values[test.Patient == p] 
    WEEK[p] = test.Weeks.values[test.Patient == p]
# Out:
# 1/1 [==============================] - 5s 5s/step
# 2/2 [==============================] - 11s 5s/step
# 15/15 [==============================] - 100s 7s/step
# 10/10 [==============================] - 66s 7s/step
# 13/13 [==============================] - 75s 6s/step

# %%
for k in sub.Patient_Week.values:
    p, w = k.split('_')
    w = int(w) 
    
    fvc = A_test[p] * w + B_test[p]
    sub.loc[sub.Patient_Week == k, 'FVC'] = fvc
    sub.loc[sub.Patient_Week == k, 'Confidence'] = (
        P_test[p] - A_test[p] * abs(WEEK[p] - w) 
)

# %%
sub.head()
# Out:
#                     Patient_Week   FVC  Confidence
# 0  ID00419637202311204720264_-12  3020   70.186855
# 1  ID00421637202311550012437_-12  2739   82.045291
# 2  ID00422637202311677017371_-12  1930   76.672493
# 3  ID00423637202312137826377_-12  3294   79.258903
# 4  ID00426637202313170790466_-12  2925   71.824968

# %%
sub[["Patient_Week","FVC","Confidence"]].to_csv("submission.csv", index=False)

# %%
ROOT = "./Dataset/"
BATCH_SIZE=128

tr = pd.read_csv(f"{ROOT}/train.csv")
tr.drop_duplicates(keep=False, inplace=True, subset=['Patient','Weeks'])
chunk = pd.read_csv(f"{ROOT}/test.csv")

print("add infos")
sub = pd.read_csv(f"{ROOT}/sample_submission.csv")
sub['Patient'] = sub['Patient_Week'].apply(lambda x:x.split('_')[0])
sub['Weeks'] = sub['Patient_Week'].apply(lambda x: int(x.split('_')[-1]))
sub =  sub[['Patient','Weeks','Confidence','Patient_Week']]
sub = sub.merge(chunk.drop('Weeks', axis=1), on="Patient")
# Out:
# add infos

# %%
tr['WHERE'] = 'train'
chunk['WHERE'] = 'val'
sub['WHERE'] = 'test'
data = tr.append([chunk, sub])

# %%
print(tr.shape, chunk.shape, sub.shape, data.shape)
print(tr.Patient.nunique(), chunk.Patient.nunique(), sub.Patient.nunique(), 
      data.Patient.nunique())
# Out:
# (1535, 8) (5, 8) (730, 10) (2270, 10)
# 176 5 5 176

# %%
data['min_week'] = data['Weeks']
data.loc[data.WHERE=='test','min_week'] = np.nan
data['min_week'] = data.groupby('Patient')['min_week'].transform('min')

# %%
base = data.loc[data.Weeks == data.min_week]
base = base[['Patient','FVC']].copy()
base.columns = ['Patient','min_FVC']
base['nb'] = 1
base['nb'] = base.groupby('Patient')['nb'].transform('cumsum')
base = base[base.nb==1]
base.drop('nb', axis=1, inplace=True)

# %%
data = data.merge(base, on='Patient', how='left')
data['base_week'] = data['Weeks'] - data['min_week']
del base

# %%
COLS = ['Sex','SmokingStatus'] #,'Age'
FE = []
for col in COLS:
    for mod in data[col].unique():
        FE.append(mod)
        data[mod] = (data[col] == mod).astype(int)

# %%
data['age'] = (data['Age'] - data['Age'].min() ) / ( data['Age'].max() - data['Age'].min() )
data['BASE'] = (data['min_FVC'] - data['min_FVC'].min() ) / ( data['min_FVC'].max() - data['min_FVC'].min() )
data['week'] = (data['base_week'] - data['base_week'].min() ) / ( data['base_week'].max() - data['base_week'].min() )
data['percent'] = (data['Percent'] - data['Percent'].min() ) / ( data['Percent'].max() - data['Percent'].min() )
FE += ['age','percent','week','BASE']

# %%
tr = data.loc[data.WHERE=='train']
chunk = data.loc[data.WHERE=='val']
sub = data.loc[data.WHERE=='test']
del data

# %%
tr.shape, chunk.shape, sub.shape
# Out:
# ((1535, 22), (5, 22), (730, 22))

# %%
C1, C2 = tf.constant(70, dtype='float32'), tf.constant(1000, dtype="float32")
def score(y_true, y_pred):
    tf.dtypes.cast(y_true, tf.float32)
    tf.dtypes.cast(y_pred, tf.float32)
    sigma = y_pred[:, 2] - y_pred[:, 0]
    fvc_pred = y_pred[:, 1]
    
    sigma_clip = tf.maximum(sigma, C1)
    delta = tf.abs(y_true[:, 0] - fvc_pred)
    delta = tf.minimum(delta, C2)
    sq2 = tf.sqrt( tf.dtypes.cast(2, dtype=tf.float32) )
    metric = (delta / sigma_clip)*sq2 + tf.math.log(sigma_clip* sq2)
    return K.mean(metric)

def qloss(y_true, y_pred):
    qs = [0.2, 0.50, 0.8]
    q = tf.constant(np.array([qs]), dtype=tf.float32)
    e = y_true - y_pred
    v = tf.maximum(q*e, (q-1)*e)
    return K.mean(v)

def mloss(_lambda):
    def loss(y_true, y_pred):
        return _lambda * qloss(y_true, y_pred) + (1 - _lambda)*score(y_true, y_pred)
    return loss

def laplace_log_likelihood(actual_fvc, predicted_fvc, confidence, return_values = False):
    """
    Calculates the modified Laplace Log Likelihood score for this competition.
    """
    sd_clipped = np.maximum(confidence, 70)
    delta = np.minimum(np.abs(actual_fvc - predicted_fvc), 1000)
    metric = - np.sqrt(2) * delta / sd_clipped - np.log(np.sqrt(2) * sd_clipped)

    if return_values:
        return metric
    else:
        return np.mean(metric)

def make_model(nh):
    z = L.Input((nh,), name="Patient")
    x = L.Dense(100, activation="relu", name="d1")(z)
    x = L.Dense(100, activation="relu", name="d2")(x)
    p1 = L.Dense(3, activation="linear", name="p1")(x)
    p2 = L.Dense(3, activation="relu", name="p2")(x)
    preds = L.Lambda(lambda x: x[0] + tf.cumsum(x[1], axis=1), 
                     name="preds")([p1, p2])
    
    model = M.Model(z, preds, name="CNN")
    #model.compile(loss=qloss, optimizer="adam", metrics=[score])
    model.compile(loss=mloss(0.8), optimizer=tf.keras.optimizers.legacy.Adam(lr=0.1, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.01, amsgrad=False), metrics=[score])
    return model

# %%
## GET TRAINING DATA AND TARGET VALUE

# get target value
y  = tr['FVC'].values

# get training & test data
X_train = tr[FE].values
X_test = sub[FE].values


nh = X_train.shape[1]

# instantiate target arrays
train_preds = np.zeros((X_train.shape[0], 3))
test_preds = np.zeros((X_test.shape[0], 3))

# %%
net = make_model(nh)
print(net.summary())
print(net.count_params())
# Out:
# Model: "CNN"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Patient (InputLayer)           [(None, 9)]          0           []
#
#  d1 (Dense)                     (None, 100)          1000        ['Patient[0][0]']
#
#  d2 (Dense)                     (None, 100)          10100       ['d1[0][0]']
#
#  p1 (Dense)                     (None, 3)            303         ['d2[0][0]']
#
#  p2 (Dense)                     (None, 3)            303         ['d2[0][0]']
#
#  preds (Lambda)                 (None, 3)            0           ['p1[0][0]',
#                                                                   'p2[0][0]']
#
# ==================================================================================================
# Total params: 11,706
# Trainable params: 11,706
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 11706
# C:\Users\user\AppData\Roaming\Python\Python37\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
y = y.astype(np.float32)

# %%
y
# Out:
# array([2315., 2214., 2061., ..., 2908., 2975., 2774.], dtype=float32)

# %%
model_cnt = 1
# instantiate target arrays
globals()['train_preds_{}'.format(model_cnt)] = np.zeros((X_train.shape[0], 3))
globals()['test_preds_{}'.format(model_cnt)] = np.zeros((X_test.shape[0], 3))

NFOLD = 5
gkf = GroupKFold(n_splits=NFOLD)
groups = tr['Patient'].values

cnt = 0
EPOCHS = 800
BATCH_SIZE=128

for tr_idx, val_idx in gkf.split(X_train,y, groups):
    cnt += 1
    print(f"FOLD {cnt}")
    net = make_model(nh)
    net.fit(X_train[tr_idx], y[tr_idx], batch_size=BATCH_SIZE, epochs=EPOCHS,validation_data=(X_train[val_idx], y[val_idx]), verbose=0) #
    print("train", net.evaluate(X_train[tr_idx], y[tr_idx], verbose=0, batch_size=BATCH_SIZE))
    print("val", net.evaluate(X_train[val_idx], y[val_idx], verbose=0, batch_size=BATCH_SIZE))
        #print("predict val...")
    globals()['train_preds_{}'.format(model_cnt)][val_idx] = net.predict(X_train[val_idx], batch_size=BATCH_SIZE, verbose=0)
    print("predict test...")
    globals()['test_preds_{}'.format(model_cnt)] += net.predict(X_test, batch_size=BATCH_SIZE, verbose=0) / NFOLD
# Out:
# FOLD 1
# C:\Users\user\AppData\Roaming\Python\Python37\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# train [39.97890090942383, 6.4780755043029785]
# val [42.9398307800293, 6.570479869842529]
# predict test...
# FOLD 2
# train [37.23153305053711, 6.445546627044678]
# val [55.326873779296875, 6.855808734893799]
# predict test...
# FOLD 3
# train [40.00955581665039, 6.492117881774902]
# val [49.466732025146484, 6.986354827880859]
# predict test...
# FOLD 4
# train [40.973228454589844, 6.5300703048706055]
# val [48.18013381958008, 6.636444091796875]
# predict test...
# FOLD 5
# train [40.739933013916016, 6.515606880187988]
# val [47.118682861328125, 6.858654022216797]
# predict test...

# %%
predicted_fvc = globals()['train_preds_{}'.format(model_cnt)][:,1]
confidence = globals()['train_preds_{}'.format(model_cnt)][:,2]-globals()['train_preds_{}'.format(model_cnt)][:,0]
model_score = laplace_log_likelihood(actual_fvc = y, predicted_fvc = predicted_fvc, confidence = confidence,
                       return_values = False)
print('Overall Score: ', model_score)
# Out:
# Overall Score:  -6.713956294474655
